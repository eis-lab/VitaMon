# %%
import numpy as np
from matplotlib import pyplot
from scipy import signal, misc
from sys import getsizeof

import tensorflow as tf
import pandas as pd
from os import walk 
import time

from matplotlib.pyplot import figure

from numpy import genfromtxt
from datetime import datetime

path = r'DATA_FOLDER_PATH'

# %%
mobile_accel = np.genfromtxt(path + '/Mobile_device_Accelerometer.csv', delimiter=',')
ecg_accel = np.genfromtxt(path + '/ECG_device_Accelerometer.csv', delimiter=',')
print(mobile_accel.shape, ecg_accel.shape)

# %%
# datetime.fromtimestamp(1554711352.329)
# Out:
# datetime.datetime(2019, 4, 8, 17, 15, 52, 329000)

# %%
# 08/04/2019 20:36:38.451
# datetime.fromtimestamp(1554723398.451)
# Out:
# datetime.datetime(2019, 4, 8, 20, 36, 38, 451000)

# %%
datetime.fromtimestamp(1542655780.009)
# Out:
# datetime.datetime(2018, 11, 20, 3, 29, 40, 9000)

# %%
figure(num=None, figsize=(14, 6), dpi=80, facecolor='w', edgecolor='k')
pyplot.plot(mobile_accel[:3000,1:4])

# %%
figure(num=None, figsize=(14, 6), dpi=80, facecolor='w', edgecolor='k')
pyplot.plot(ecg_accel[:3000,1:4])
